# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Sep  2 10:39:59 2020

@author: c3121
"""


#%%
import os
import keras
import numpy as np
from PIL import Image
import cv2
import matplotlib.pyplot as plt
def apply_color_mask(hsv,img,low,high):
    # Apply color mask to image
    mask = cv2.inRange(hsv, low, high)
    res = cv2.bitwise_and(img,img, mask= mask)
    return res
#%%
base_path = r'diease'#這裡要改
#print('1')
for root, dirs, files in os.walk(base_path):
    #print('1')
    for file in files:
        if file.endswith('.JPG'):
            #print('1')
            filename = os.path.join(root, file)
            file_size = os.path.getsize(filename)
            category_name = os.path.basename(root)
            
            print(filename)
            im = cv2.imread(filename)

            #im = cv2.imread(r'diease/c47ccf21-5249-4a95-8d33-0d640e3529f7___RS_L.Scorch 0158.JPG')
            im=cv2.resize(im,(128,128), interpolation = cv2.INTER_CUBIC)
            im_hsv=cv2.cvtColor(im,cv2.COLOR_BGR2HSV)
            im=cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
            plt.subplot(1,2,1)
            plt.imshow(im)
            im_gray=cv2.cvtColor(im,cv2.COLOR_RGB2GRAY)
            #im_gray=cv2.GaussianBlur(im_gray,(3,3),0)
            #im_gray=cv2.Canny(im_gray,100,200)
            #plt.subplot(2,2,1)
            #plt.imshow(im)
            #plt.subplot(2,2,2)
            #plt.imshow(im_gray,cmap='gray')
            #plt.show()
            #%%
            mask_g = cv2.inRange(im_hsv,(20,43,46) ,(99,255,255) )
            im_res_g=cv2.bitwise_and(im,im,mask=mask_g)
            #plt.subplot(2,2,3)
            #plt.imshow(im_res_g)
            mask_brown1=cv2.inRange(im_hsv,(0,80,50),(20,255,255))
            im_res_brown1=cv2.bitwise_and(im,im,mask= mask_brown1 )
            mask_brown2=cv2.inRange(im_hsv,(160,80,50),(180,255,255))
            im_res_brown2=cv2.bitwise_and(im,im,mask=mask_brown2)
            im_res_brown=cv2.add(im_res_brown1,im_res_brown2)
            plt.subplot(1,2,2)
            plt.imshow(cv2.add(im_res_brown1,im_res_brown2))

                #plt.show()
                #im_no_background=cv2.add(cv2.add(im_res_brown1,im_res_brown2),im_res_g)
                #im_no_background_gray=cv2.cvtColor(im_no_background,cv2.COLOR_RGB2GRAY)
                #plt.imshow(im_no_background)
                #plt.show()
                #%%
                #( cnts, _) = cv2.findContours(im_no_background_gray.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

                #clone = im.copy()

                #cv2.drawContours(clone, cnts, -1, (0, 0, 0), 2)
                #clone_hsv=cv2.cvtColor(clone,cv2.COLOR_RGB2HSV)
                #mask_green = cv2.inRange(im_hsv,(20,43,46) ,(99,255,255) )
                #mask_brown3=cv2.inRange(im_hsv,(0,80,0),(20,255,255))
                #mask_brown4=cv2.inRange(im_hsv,(160,80,0),(180,255,255))
                #clone_res_g=cv2.bitwise_and(clone,clone,mask=mask_green)
                #clone_res_brown=cv2.bitwise_and(clone,clone,mask=cv2.add(mask_brown3,mask_brown4))
                #clone_res=cv2.bitwise_and(clone,clone,mask=cv2.add(mask_green,cv2.add(mask_brown3,mask_brown4)))
                #clone_res_brown_gray=cv2.cvtColor(clone_res_brown,cv2.COLOR_RGB2GRAY)
                #plt.subplot(1,2,1)
                #plt.imshow(clone_res_g)
                #plt.subplot(1,2,2)
                #plt.imshow(clone_res)
                #plt.show()
                #plt.subplot(1,2,2)
                #plt.imshow(clone_res_brown)
            plt.show()
                #cv2.imwrite('brown_'+filename,im_res_brown)
# Out:
# diease/64dcb8c1-3f29-46be-98b4-a01121dd9223___RS_L.Scorch 1243.JPG
# diease/76855c51-76ed-44c2-9020-f4621d0f61ab___RS_L.Scorch 1438.JPG
# diease/11c7dacf-e6f4-4a31-a89b-e0d221eefdbf___RS_L.Scorch 1032_flipLR.JPG
# diease/29c3d239-be01-4d55-81fa-37870bc305e9___RS_L.Scorch 0806_flipLR.JPG
# diease/51d08a3c-0a36-472d-9079-06e4746488b5___RS_L.Scorch 0052_flipLR.JPG
# diease/3b9454d1-8c70-4bca-ba30-60689208c217___RS_L.Scorch 1245.JPG
# diease/bd89b21e-7f53-490d-94ab-0eb54a79c465___RS_L.Scorch 1206_flipLR.JPG
# diease/b3eb2228-f38e-4472-a39e-3e39917bac3d___RS_L.Scorch 9982.JPG
# diease/4a48fdfb-bcba-4e5d-972e-44d35ffce2a5___RS_L.Scorch 1491_flipLR.JPG
# diease/0c389f38-7be5-4218-803d-dfde6e8a7832___RS_L.Scorch 1065_flipLR.JPG
# diease/8b11b530-7a05-4fbd-81a4-a057cbf44d9d___RS_L.Scorch 0001.JPG
# diease/75a100f6-e856-4bad-bd32-14fa9f0f6f5a___RS_L.Scorch 1279.JPG
# diease/bfde826a-4ff5-49e0-b6b8-f3a14f4c7eeb___RS_L.Scorch 9990_flipLR.JPG
# diease/9e846d22-58de-43af-97b3-b52eec137369___RS_L.Scorch 1230.JPG
# diease/9d368867-837e-442b-a45f-d0d3d3f4cf13___RS_L.Scorch 0057_flipLR.JPG
# diease/9198c21b-7225-47e7-a7e5-459cf5a48e2d___RS_L.Scorch 1403.JPG
# diease/6c230d35-6763-4d95-a766-e64a2d165d70___RS_L.Scorch 1465.JPG
# diease/6c230d35-6763-4d95-a766-e64a2d165d70___RS_L.Scorch 1465_flipLR.JPG
# diease/54529a6a-f918-4460-8361-b8cb41841183___RS_L.Scorch 0782_flipLR.JPG
# diease/74f93b50-567b-4858-af63-7a54774f018e___RS_L.Scorch 1259.JPG
# diease/b4f9293b-406b-4be2-8273-5329faac034c___RS_L.Scorch 0923_flipLR.JPG
# diease/5251a1e3-9502-4f78-ad85-1983b62861b0___RS_L.Scorch 0987.JPG
# diease/76e3f721-2ce3-4f3d-a533-72c3716540c6___RS_L.Scorch 1310.JPG
# diease/aed8624d-676c-453f-a0af-cfee0fac55f9___RS_L.Scorch 0869.JPG
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-52e49ffd626d> in <module>
#      87                 #plt.subplot(1,2,2)
#      88                 #plt.imshow(clone_res_brown)
# ---> 89             plt.show()
#      90                 #cv2.imwrite('brown_'+filename,im_res_brown)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     640         else:
#     641             im, l, b, trans = self.make_image(
# --> 642                 renderer, renderer.get_image_magnification())
#     643             if im is not None:
#     644                 renderer.draw_image(gc, l, b, im)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     925                 else self.figure.bbox)
#     926         return self._make_image(self._A, bbox, transformed_bbox, clip,
# --> 927                                 magnification, unsampled=unsampled)
#     928
#     929     def _check_unsampled_image(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     549                 alpha = self._get_scalar_alpha()
#     550                 output_alpha = _resample(  # resample alpha channel
# --> 551                     self, A[..., 3], out_shape, t, alpha=alpha)
#     552                 output = _resample(  # resample rgb channels
#     553                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     195                     alpha,
#     196                     image_obj.get_filternorm(),
# --> 197                     image_obj.get_filterrad())
#     198     return out
#     199
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __array__(self, *args, **kwargs)
#    1395     def __array__(self, *args, **kwargs):
#    1396         """Array interface to get at this Transform's affine matrix."""
# -> 1397         return self.get_affine().get_matrix()
#    1398
#    1399     def transform(self, values):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in get_affine(self)
#    2370         else:
#    2371             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2372                                    self._a.get_affine().get_matrix()))
#    2373
#    2374     def inverted(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in get_affine(self)
#    2370         else:
#    2371             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2372                                    self._a.get_affine().get_matrix()))
#    2373
#    2374     def inverted(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in get_affine(self)
#    2369             return self._b.get_affine()
#    2370         else:
# -> 2371             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2372                                    self._a.get_affine().get_matrix()))
#    2373
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in get_affine(self)
#    2366     def get_affine(self):
#    2367         # docstring inherited
# -> 2368         if not self._b.is_affine:
#    2369             return self._b.get_affine()
#    2370         else:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in <lambda>(self)
#    2332
#    2333     depth = property(lambda self: self._a.depth + self._b.depth)
# -> 2334     is_affine = property(lambda self: self._a.is_affine and self._b.is_affine)
#    2335     is_separable = property(
#    2336         lambda self: self._a.is_separable and self._b.is_separable)
#
# KeyboardInterrupt:
